# %%
from helper import Helper
helper = Helper()

# %% [markdown]
# # Model evaluation

# %%
DATA_DIR = "datasets/split_images"
MODEL_NAME = "vtc_final_model"  # The name of the model to load.

helper.evaluate_model(DATA_DIR, MODEL_NAME)
# Out:
# Found 1156 images belonging to 3 classes.
# Found 329 images belonging to 3 classes.
# Found 169 images belonging to 3 classes.
#
# Training evaluation:
# 1156/1156 [==============================] - 23s 19ms/step - loss: 2.3800e-04 - acc: 1.0000
#
# Validation evaluation:
# 329/329 [==============================] - 6s 18ms/step - loss: 0.0399 - acc: 0.9939
#
# Testing evaluation:
# 169/169 [==============================] - 3s 18ms/step - loss: 0.1130 - acc: 0.9822

# %% [markdown]
# # Model miss-classifications

# %%
ALL_DATA_DIR = "datasets/main"  # The root dataset directory.

helper.get_wrong_samples(ALL_DATA_DIR, MODEL_NAME)
# Out:
# Classes: ['emergency', 'other', 'truck']
#
# For the (emergency) class:
# 0 50 Miss classification: emergency 002115_18.jpg
# 100 samples done
# 200 samples done
# 300 samples done
# 400 samples done
#
# For the (other) class:
# 100 samples done
# 200 samples done
# 300 samples done
# 400 samples done
# 500 samples done
# 600 samples done
# 1 678 Miss classification: other 0_P1010030.jpg
# 700 samples done
# 1 746 Miss classification: other 0_test_039.jpg
# 800 samples done
#
# For the (truck) class:
# 2 97 Miss classification: truck 000524_04.jpg
# 100 samples done
# 200 samples done
# 2 215 Miss classification: truck 002187_10.jpg
# 300 samples done
